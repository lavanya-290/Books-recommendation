# %%
import pandas as pd
import re

# %%
books=pd.read_excel(r'C:\Users\L2456223\Documents\datasets\Book recommendation system dataset\books.xlsx')

# %%
ratings=pd.read_excel(r'C:\Users\L2456223\Documents\datasets\Book recommendation system dataset\ratings.xlsx')
users=pd.read_excel(r'C:\Users\L2456223\Documents\datasets\Book recommendation system dataset\users.xlsx')

# %%
ratings.head()
# Out:
#    User-ID        ISBN  Book-Rating
# 0   276725  034545104X            0
# 1   276726   155061224            5
# 2   276727   446520802            0
# 3   276729  052165615X            3
# 4   276729   521795028            6

# %%
users.head()
# Out:
#    User-ID                            Location   Age
# 0        1                  nyc, new york, usa   NaN
# 1        2           stockton, california, usa  18.0
# 2        3     moscow, yukon territory, russia   NaN
# 3        4           porto, v.n.gaia, portugal  17.0
# 4        5  farnborough, hants, united kingdom   NaN

# %%
books.head()
# Out:
#         ISBN                                         Book-Title  \
# 0  195153448                                Classical Mythology
# 1    2005018                                       Clara Callan
# 2   60973129                               Decision in Normandy
# 3  374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  393045218                             The Mummies of Urumchi
#
#             Book-Author Year-Of-Publication                   Publisher  \
# 0    Mark P. O. Morford                2002     Oxford University Press
# 1  Richard Bruce Wright                2001       HarperFlamingo Canada
# 2          Carlo D'Este                1991             HarperPerennial
# 3      Gina Bari Kolata                1999        Farrar Straus Giroux
# 4       E. J. W. Barber                1999  W. W. Norton &amp; Company
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# ...

# %%
# Define the regular expression pattern to match special characters
pattern = r'[^\w\s]'

# Replace all special characters with an empty string
books['Book-Title'] = books['Book-Title'].str.replace(pattern, '')
# Out:
# C:\Users\L2456223\AppData\Local\Temp\ipykernel_7844\2736665987.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   books['Book-Title'] = books['Book-Title'].str.replace(pattern, '')

# %%
books.shape
#books.isduplicated(books['ISBN'])
# Out:
# (271360, 8)

# %%
ratings['User-ID'].value_counts()
# Out:
# 11676     13602
# 198711     7550
# 153662     6109
# 98391      5891
# 35859      5850
#           ...
# 104999        1
# 105002        1
# 105008        1
# 105014        1
# 123969        1
# Name: User-ID, Length: 95513, dtype: int64

# %%
x = ratings['User-ID'].value_counts() > 200 #users_w_high_ratings

# %%
y=x[x].index  #fetching indexes of those userids

# %%
filtered_ratings = ratings[ratings['User-ID'].isin(y)] #fetching full rows of users

# %%
filtered_ratings.head()
# Out:
#       User-ID        ISBN  Book-Rating
# 1456   277427  002542730X           10
# 1457   277427    26217457            0
# 1458   277427  003008685X            8
# 1459   277427    30615321            0
# 1460   277427    60002050            0

# %%
filtered_ratings.shape
# Out:
# (482728, 3)

# %%
ratings_books=filtered_ratings.merge(books, on='ISBN')

# %%
ratings_books.head()
# Out:
#    User-ID        ISBN  Book-Rating  \
# 0   277427  002542730X           10
# 1     3363  002542730X            0
# 2    11676  002542730X            6
# 3    12538  002542730X           10
# 4    13552  002542730X            0
#
#                                           Book-Title        Book-Author  \
# 0  Politically Correct Bedtime Stories Modern Tal...  James Finn Garner
# 1  Politically Correct Bedtime Stories Modern Tal...  James Finn Garner
# 2  Politically Correct Bedtime Stories Modern Tal...  James Finn Garner
# 3  Politically Correct Bedtime Stories Modern Tal...  James Finn Garner
# 4  Politically Correct Bedtime Stories Modern Tal...  James Finn Garner
#
#   Year-Of-Publication                  Publisher  \
# 0                1994  John Wiley &amp; Sons Inc
# 1                1994  John Wiley &amp; Sons Inc
# 2                1994  John Wiley &amp; Sons Inc
# 3                1994  John Wiley &amp; Sons Inc
# 4                1994  John Wiley &amp; Sons Inc
#
# ...

# %%
ratings_books.shape
# Out:
# (446867, 5)

# %%
count_zero_ratings = ratings_books['Book-Rating'].value_counts().get(0, 0)

# %%
count_zero_ratings
# Out:
# 334524

# %%
ratings_books.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 446867 entries, 0 to 446866
# Data columns (total 10 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   User-ID              446867 non-null  int64
#  1   ISBN                 446867 non-null  object
#  2   Book-Rating          446867 non-null  int64
#  3   Book-Title           446733 non-null  object
#  4   Book-Author          446867 non-null  object
#  5   Year-Of-Publication  446867 non-null  object
#  6   Publisher            446865 non-null  object
#  7   Image-URL-S          446867 non-null  object
#  8   Image-URL-M          446867 non-null  object
#  9   Image-URL-L          446864 non-null  object
# dtypes: int64(2), object(8)
# memory usage: 37.5+ MB

# %%
number_rating = ratings_books.groupby('Book-Title')['Book-Rating'].count().reset_index()

# %%
ratings_books.drop(columns=['Year-Of-Publication','Publisher','Image-URL-S','Image-URL-M','Image-URL-L'],inplace=True)

# %%
number_rating.sort_values(by=['Book-Rating'],ascending=False).reset_index().drop(columns=['index'])
# Out:
#                                                Book-Title  Book-Rating
# 0                                             Wild Animus          323
# 1                                    Bridget Joness Diary          250
# 2                                The Lovely Bones A Novel          241
# 3                                       The Pelican Brief          216
# 4                                            The Notebook          216
# ...                                                   ...          ...
# 152727  La MÃƒÃÂthode simple pour en finir avec la cig...            1
# 152728             La MÃƒÃÂtamorphose et autres rÃƒÃÂcits            1
# 152729  La Mythologie  Ses dieu ses hÃƒÃÂros ses lÃƒÃÂ...            1
# 152730                                 La Mujer Y El Mono            1
# 152731                                   ÃƒÃthique en toc            1
#
# [152732 rows x 2 columns]

# %%
number_rating.rename(columns={'Book-Rating': 'number of ratings'},inplace=True)

# %%
ratings_books.shape
# Out:
# (446867, 10)

# %%
final_ratings = ratings_books.merge(number_rating, on='Book-Title').sort_values(by=['number of ratings'],ascending=False)

# %%
final_ratings.head(3)
# Out:
#        User-ID       ISBN  Book-Rating   Book-Title   Book-Author  \
# 12641   206979  971880107            0  Wild Animus  Rich Shapero
# 12696   246617  971880107            0  Wild Animus  Rich Shapero
# 12431    39773  971880107            0  Wild Animus  Rich Shapero
#
#        number of ratings
# 12641                323
# 12696                323
# 12431                323

# %%
final_ratings.tail()
# Out:
#         User-ID        ISBN  Book-Rating  \
# 354597    98391   441010393            9
# 354596    98391   441010318            8
# 354595    98391   441010156            9
# 354594    98391  044101013X           10
# 446732   250764   515069434            0
#
#                                     Book-Title        Book-Author  \
# 354597      Signals The Exploration Chronicles    Kevin D. Randle
# 354596                   The Sword of the Land  Noel-Anne Brennan
# 354595                             Red Thunder        John Varley
# 354594                                Angelica       Sharon Shinn
# 446732  Lady Laughing Eyes To Have and to Hold          Lee Damon
#
#         number of ratings
# 354597                  1
# 354596                  1
# 354595                  1
# 354594                  1
# 446732                  1

# %%
final_ratings.shape
# Out:
# (446733, 6)

# %%
final_ratings=final_ratings[final_ratings['number of ratings']>=50]

# %%
final_ratings.head()
# Out:
#        User-ID       ISBN  Book-Rating   Book-Title   Book-Author  \
# 12641   206979  971880107            0  Wild Animus  Rich Shapero
# 12696   246617  971880107            0  Wild Animus  Rich Shapero
# 12431    39773  971880107            0  Wild Animus  Rich Shapero
# 12430    39646  971880107            0  Wild Animus  Rich Shapero
# 12429    39281  971880107            0  Wild Animus  Rich Shapero
#
#        number of ratings
# 12641                323
# 12696                323
# 12431                323
# 12430                323
# 12429                323

# %%
final_ratings.shape
# Out:
# (51168, 6)

# %%
final_ratings.drop_duplicates(['User-ID','Book-Title'],inplace=True)

# %%
final_ratings
# Out:
#         User-ID       ISBN  Book-Rating                 Book-Title  \
# 12641    206979  971880107            0                Wild Animus
# 12696    246617  971880107            0                Wild Animus
# 12431     39773  971880107            0                Wild Animus
# 12430     39646  971880107            0                Wild Animus
# 12429     39281  971880107            0                Wild Animus
# ...         ...        ...          ...                        ...
# 102800   230496  380727501            0  Notes from a Small Island
# 102799   222296  380727501            0  Notes from a Small Island
# 102798   211426  380727501            0  Notes from a Small Island
# 102797   208671  380727501            0  Notes from a Small Island
# 102802   232131  380727501            0  Notes from a Small Island
#
#          Book-Author  number of ratings
# 12641   Rich Shapero                323
# 12696   Rich Shapero                323
# ...

# %%
import scipy.stats as stats
import statsmodels.api as sm

# %%
# Perform Anderson-Darling test
anderson_result = stats.anderson(final_ratings, 'norm')
print("Anderson-Darling test:")
print("AD Statistic:", anderson_result.statistic)
print("Critical Values:", anderson_result.critical_values)
print("Significance Levels:", anderson_result.significance_level)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[239], line 2
#       1 # Perform Anderson-Darling test
# ----> 2 anderson_result = stats.anderson(final_ratings, 'norm')
#       3 print("Anderson-Darling test:")
#       4 print("AD Statistic:", anderson_result.statistic)
#
# File C:\anaconda\lib\site-packages\scipy\stats\_morestats.py:1943, in anderson(x, dist)
#    1941 if dist not in dists:
#    1942     raise ValueError(f"Invalid distribution; dist must be in {dists}.")
# -> 1943 y = sort(x)
#    1944 xbar = np.mean(x, axis=0)
#    1945 N = len(y)
#
# File <__array_function__ internals>:180, in sort(*args, **kwargs)
#
# File C:\anaconda\lib\site-packages\numpy\core\fromnumeric.py:1004, in sort(a, axis, kind, order)
#    1002 else:
#    1003     a = asanyarray(a).copy(order="K")
# -> 1004 a.sort(axis=axis, kind=kind, order=order)
#    1005 return a
#
# ...

# %%
final_ratings1 = final_ratings[final_ratings['Book-Rating'] != 0]

# %%
final_ratings1
# Out:
#         User-ID       ISBN  Book-Rating    Book-Title         Book-Author  \
# 12427     38023  971880107            9   Wild Animus        Rich Shapero
# 12426     37950  971880107            3   Wild Animus        Rich Shapero
# 12699    249862  971880107            1   Wild Animus        Rich Shapero
# 12416     31826  971880107            1   Wild Animus        Rich Shapero
# 12414     30972  971880107            1   Wild Animus        Rich Shapero
# ...         ...        ...          ...           ...                 ...
# 157113    16106  743500504            9  The Carousel  Richard Paul Evans
# 157114    35857  743500504            9  The Carousel  Richard Paul Evans
# 157115    94923  743500504            5  The Carousel  Richard Paul Evans
# 157127   236757  385311079            5  The Carousel         Belva Plain
# 157089    66680  440216842            7  The Carousel         Belva Plain
#
#         number of ratings
# 12427                 323
# ...

# %%
book_pivot1 = final_ratings1.pivot_table(columns='User-ID', index='Book-Title', values="Book-Rating",aggfunc='mean')
book_pivot.fillna(0, inplace=True)

# %%
book_pivot1
# Out:
# User-ID                                             254     2276    2766    \
# Book-Title
# 1st to Die A Novel                                     NaN     NaN     NaN
# 2nd Chance                                             NaN    10.0     NaN
# 4 Blondes                                              NaN     NaN     NaN
# 84 Charing Cross Road                                  NaN     NaN     NaN
# A Bend in the Road                                     NaN     NaN     7.0
# ...                                                    ...     ...     ...
# Wuthering Heights                                      NaN     NaN     NaN
# Year of Wonders                                        NaN     NaN     NaN
# You Belong To Me                                       NaN     NaN     NaN
# Zen and the Art of Motorcycle Maintenance An In...     NaN     NaN     NaN
# Zoya                                                   NaN     NaN     NaN
#
# ...

# %%
book_pivot = final_ratings.pivot_table(columns='User-ID', index='Book-Title', values="Book-Rating")
book_pivot.fillna(0, inplace=True)

# %%
book_pivot
# Out:
# User-ID                                             254     2276    2766    \
# Book-Title
# 1st to Die A Novel                                     0.0     0.0     0.0
# 2nd Chance                                             0.0    10.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# 84 Charing Cross Road                                  0.0     0.0     0.0
# A Bend in the Road                                     0.0     0.0     7.0
# ...                                                    ...     ...     ...
# Wuthering Heights                                      0.0     0.0     0.0
# Year of Wonders                                        0.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance An In...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
#
# ...

# %%
from scipy.sparse import csr_matrix

# %%
data_sparsematrix=csr_matrix(book_pivot)

# %%
from sklearn.neighbors import NearestNeighbors

# %%
model = NearestNeighbors(n_neighbors=5,algorithm='brute')
model.fit(data_sparsematrix)
# Out:
# NearestNeighbors(algorithm='brute')

# %%
#distances, suggestions = model.kneighbors(data_sparsematrix)

# %%
#distances, suggestions = model.kneighbors(data_sparsematrix[445, :])#.values.reshape(1, -1))

# %%
distances, suggestions = model.kneighbors(book_pivot.iloc[45, :].values.reshape(1, -1))

# %%
for i in range(len(suggestions)):
    print(book_pivot.index[suggestions[i]])
# Out:
# Index(['Anne of Green Gables Anne of Green Gables Novels Paperback',
#        'Anne of the Island', 'The Cradle Will Fall', 'Secrets',
#        'The Temple of My Familiar'],
#       dtype='object', name='Book-Title')

# %%
''' to find how the algorithm is executing. mostly it uses the concept of k means clustering, that it is grouping data based 
on a measure or anything. we have to find on what basis groups are being formed. For that we will use the upper recommendation 
group for reference. i will obtain the values for each of these and check whether the ratings for this is the same'''

# %%
for i in range(len(suggestions)):
    book__title = book_pivot.index[suggestions[i]]
    book__ratings = book_pivot.loc[book_title, :]
print(book__ratings)
# Out:
# User-ID                                             254     2276    2766    \
# Book-Title
# Anne of Green Gables Anne of Green Gables Novel...     0.0     0.0     0.0
# Anne of the Island                                     0.0     0.0     0.0
# The Cradle Will Fall                                   0.0     0.0     0.0
# Secrets                                                0.0     0.0     0.0
# The Temple of My Familiar                              0.0     0.0     0.0
#
# User-ID                                             2977    3363    3757    \
# Book-Title
# Anne of Green Gables Anne of Green Gables Novel...     0.0     0.0     0.0
# Anne of the Island                                     0.0     0.0     0.0
# The Cradle Will Fall                                   0.0     0.0     0.0
# Secrets                                                0.0     0.0     0.0
# The Temple of My Familiar                              0.0     0.0     0.0
#
# ...

# %%
var=book_pivot.loc['The Chamber']

# %%
var
# Out:
# User-ID
# 254       0.0
# 2276      0.0
# 2766      0.0
# 2977      0.0
# 3363      0.0
#          ...
# 250764    0.0
# 277427    0.0
# 277478    0.0
# 277639    0.0
# 278418    0.0
# Name: The Chamber, Length: 805, dtype: float64

# %%
#Year of Wonders
